# %%
BodyFat=read.csv("BodyFat.csv")

# %%
head(BodyFat)
# Out:
#   IDNO BODYFAT DENSITY AGE WEIGHT HEIGHT ADIPOSITY NECK CHEST ABDOMEN HIP
# 1 1    12.6    1.0708  23  154.25 67.75  23.7      36.2  93.1  85.2    94.5
# 2 2     6.9    1.0853  22  173.25 72.25  23.4      38.5  93.6  83.0    98.7
# 3 3    24.6    1.0414  22  154.00 66.25  24.7      34.0  95.8  87.9    99.2
# 4 4    10.9    1.0751  26  184.75 72.25  24.9      37.4 101.8  86.4   101.2
# 5 5    27.8    1.0340  24  184.25 71.25  25.6      34.4  97.3 100.0   101.9
# 6 6    20.6    1.0502  24  210.25 74.75  26.5      39.0 104.5  94.4   107.8
#   THIGH KNEE ANKLE BICEPS FOREARM WRIST
# 1 59.0  37.3 21.9  32.0   27.4    17.1
# 2 58.7  37.3 23.4  30.5   28.9    18.2
# 3 59.6  38.9 24.0  28.8   25.2    16.6
# 4 60.1  37.3 22.8  32.4   29.4    18.2
# 5 63.2  42.2 24.0  32.2   27.7    17.7
# 6 66.0  42.0 25.6  35.7   30.6    18.8

# %%
tail(BodyFat)
# Out:
#     IDNO BODYFAT DENSITY AGE WEIGHT HEIGHT ADIPOSITY NECK CHEST ABDOMEN HIP
# 247 247  29.1    1.0308  69  215.50 70.50  30.5      40.8 113.7 107.6   110.0
# 248 248  11.5    1.0736  70  134.25 67.00  21.1      34.9  89.2  83.6    88.8
# 249 249  32.3    1.0236  72  201.00 69.75  29.1      40.9 108.5 105.0   104.5
# 250 250  28.3    1.0328  72  186.75 66.00  30.2      38.9 111.1 111.5   101.7
# 251 251  25.3    1.0399  72  190.75 70.50  27.0      38.9 108.3 101.3    97.8
# 252 252  30.7    1.0271  74  207.50 70.00  29.8      40.8 112.4 108.5   107.1
#     THIGH KNEE ANKLE BICEPS FOREARM WRIST
# 247 63.3  44.0 22.6  37.5   32.6    18.8
# 248 49.6  34.8 21.5  25.6   25.7    18.5
# 249 59.6  40.8 23.2  35.2   28.6    20.1
# 250 60.3  37.3 21.5  31.3   27.2    18.0
# 251 56.0  41.6 22.7  30.5   29.4    19.8
# 252 59.3  42.2 24.6  33.7   30.0    20.9

# %%
cor(BodyFat)
# Out:
#           IDNO         BODYFAT     DENSITY     AGE         WEIGHT
# IDNO       1.000000000  0.11095086 -0.10960539  0.34125350  0.03372794
# BODYFAT    0.110950863  1.00000000 -0.98808673  0.28917352  0.61315611
# DENSITY   -0.109605390 -0.98808673  1.00000000 -0.27763721 -0.59406188
# AGE        0.341253503  0.28917352 -0.27763721  1.00000000 -0.01274609
# WEIGHT     0.033727935  0.61315611 -0.59406188 -0.01274609  1.00000000
# HEIGHT     0.040943134 -0.08910641  0.09788114 -0.17164514  0.30827854
# ADIPOSITY  0.047717462  0.72799418 -0.71473204  0.11885126  0.88735216
# NECK       0.071112330  0.49148893 -0.47296636  0.11350519  0.83071622
# CHEST      0.120514823  0.70288516 -0.68259865  0.17644968  0.89419052
# ABDOMEN    0.121719735  0.81370622 -0.79895463  0.23040942  0.88799494
# HIP       -0.023736967  0.62569993 -0.60933143 -0.05033212  0.94088412
# THIGH     -0.080708189  0.56128438 -0.55309098 -0.20009576  0.86869354
# ...

# %%
# sombody pre-ordered the data by age.
# ADIPOSITY comes from WEIGHT and HEIGHT.
# IDNO=2, IDNO=248 pay attention to their bodyfat and age.
#

# %%
# Y (outcome) is bodyfat;
#  X is anything except density and bodyfat.

attach(BodyFat)
dim(BodyFat)
# Out:
# [1] 252  17

# %%
colnames(BodyFat)
# Out:
#  [1] "IDNO"      "BODYFAT"   "DENSITY"   "AGE"       "WEIGHT"    "HEIGHT"
#  [7] "ADIPOSITY" "NECK"      "CHEST"     "ABDOMEN"   "HIP"       "THIGH"
# [13] "KNEE"      "ANKLE"     "BICEPS"    "FOREARM"   "WRIST"

# %%
# Step 1: Analyzing Raw Data

# Look at the wrong number, and find out how they generate.

# %%
summary(BodyFat)
# Out:
#       IDNO           BODYFAT         DENSITY           AGE
#  Min.   :  1.00   Min.   : 0.00   Min.   :0.995   Min.   :22.00
#  1st Qu.: 63.75   1st Qu.:12.80   1st Qu.:1.041   1st Qu.:35.75
#  Median :126.50   Median :19.00   Median :1.055   Median :43.00
#  Mean   :126.50   Mean   :18.94   Mean   :1.056   Mean   :44.88
#  3rd Qu.:189.25   3rd Qu.:24.60   3rd Qu.:1.070   3rd Qu.:54.00
#  Max.   :252.00   Max.   :45.10   Max.   :1.109   Max.   :81.00
#      WEIGHT          HEIGHT        ADIPOSITY          NECK
#  Min.   :118.5   Min.   :29.50   Min.   :18.10   Min.   :31.10
#  1st Qu.:159.0   1st Qu.:68.25   1st Qu.:23.10   1st Qu.:36.40
#  Median :176.5   Median :70.00   Median :25.05   Median :38.00
#  Mean   :178.9   Mean   :70.15   Mean   :25.44   Mean   :37.99
#  3rd Qu.:197.0   3rd Qu.:72.25   3rd Qu.:27.32   3rd Qu.:39.42
#  Max.   :363.1   Max.   :77.75   Max.   :48.90   Max.   :51.20
#      CHEST           ABDOMEN            HIP            THIGH
# ...

# %%
# min BODYFAT is zero, which means that maybe it is a mistake, and we should use DENSITY to fix it.
# max BODYFAT is too large, which means that it is wrong too, and we should fix it.
# min HEIGHT is unlikely to exist;
# max WEIGHT should be double checked (with HEIGHT);
# max BICEPS should be double checked;
# max ADIPOSITY is unlikely to exist...

# %%
# Some "background reading"
## weight, waist, wrist, hip and foream
## Bodyfat: see the picture of the association between body shape and bodyfat.

# %%
# Step 2: Visualizing Data

# %%
hist(BODYFAT,breaks = 20)
# Out:
# Plot with title "Histogram of BODYFAT"

# %%
# do the BODYFAT comes from normal distribution
# how to check whether they come from normal distribution?
# Use Q-Q plot (quantile)

# %%
# hist of AGE, BODYFAT, WEIGHT, KNEE
## group of age / some peaks in the histogram

# %%
# seems majority of individuals weight around 175 lbs.

# SQL (database language) / Python / R

# %%
# 1. How to clean up data?
# 2. How measurements are taken? (units, precision)
# 3. ...

# %%
# Step 3: Statistical Modeling and Anlysis

# %%
## for the lecture, we look the relationship between body fat % and age.

# %%
plot(AGE,BODYFAT)
# Out:
# plot without title

# %%
# jittering/? to the data: make some noisy to the data.

# %%
# fit an SLR model
fit=lm(BODYFAT~AGE)
summary(fit)
# Out:
# Call:
# lm(formula = BODYFAT ~ AGE)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -18.0697  -5.7025   0.2846   4.8301  25.0739
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.95546    1.73576   6.312 1.25e-09 ***
# AGE          0.17786    0.03724   4.776 3.04e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 7.435 on 250 degrees of freedom
# Multiple R-squared:  0.08362,	Adjusted R-squared:  0.07996
# F-statistic: 22.81 on 1 and 250 DF,  p-value: 3.045e-06

# %%
plot(AGE, BODYFAT)
abline(reg = fit)
# Out:
# plot without title

# %%
# lots of variability in the figure;
# R-squared is very small (PROBLEM)
##### best R-squared 76%-77% ######### (if add a variable, R-squared improves 10%-20%. We should add it.)

# %%
# do prediction
# do hypothesis test

# %%
# Step 4: Dignose
## Residual plot / Standardized residual plot ? choose which one?
## Q-Q plot

# %%
# Q-Q plot 
## PHD: not normal
## Manage: normal

# %%
# influencial plot

# check which points play important roles in building our model!

# %%
# REMARK; Clean plots; Clean tables;
